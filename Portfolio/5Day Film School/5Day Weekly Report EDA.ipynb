# %% [markdown]
# 5Day Film Weekly Report EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import sklearn


data = pd.read_csv(r"D:\Programs\Data Programs\GitRep\KJK-Study-Book\Portfolio Projects\5Day Film School\5Day Data\Weekly_Report_Archives_8324_12424.csv")
df = pd.DataFrame(data)

df = df.drop(axis=0,index=0)
df.head()
# Out:
#   Weekly Report Archives Unnamed: 1 Unnamed: 2       Unnamed: 3  \
# 1                   Name   Subitems     Number  Leads this week
# 2                 Philip        NaN          1                0
# 3                Stephen        NaN          2                0
# 4                Ahlyzik        NaN          3                0
# 5                   Rich        NaN          4                0
#
#          Unnamed: 4      Unnamed: 5  Unnamed: 6   Unnamed: 7       Unnamed: 8  \
# 1  Leads last 4 wks  Open Rate (E1)  Reply Rate  Bounce Rate  Sending per day
# 2                 1            52.8         NaN          NaN               60
# 3                 0            42.3         NaN          NaN               50
# 4                 0             NaN         NaN          NaN               50
# 5                 0            45.5         2.2          0.5              200
#
#      Unnamed: 9       Unnamed: 10 Unnamed: 11 Unnamed: 12
# ...

# %%
df.columns = df.iloc[0]
clean_df = df.drop(df.index[0])
clean_df
# Out:
# 1       Name Subitems Number Leads this week Leads last 4 wks Open Rate (E1)  \
# 2     Philip      NaN      1               0                1           52.8
# 3    Stephen      NaN      2               0                0           42.3
# 4    Ahlyzik      NaN      3               0                0            NaN
# 5       Rich      NaN      4               0                0           45.5
# 6      Tyler      NaN      5               0                1            NaN
# ..       ...      ...    ...             ...              ...            ...
# 200  Chris B      NaN     19               1                2           52.1
# 201     Greg      NaN     20               0                2           57.8
# 202     Andy      NaN     21               3                8             41
# 203  Simon G      NaN     22               2                2             31
# 204      NaN      NaN    NaN              12               49          581.9
#
# ...

# %% [markdown]
# Want to lift all the data for each student, using student names as identifier, and create a new table with their average statistics...?
# What I really want is individual tables for each week,
# and a dataset that calls on the individual tables for data.

# %% [markdown]
# E.g., 4 individual tables with student names;
# Callable for example to: view historical/timeseries improvements for each student, and analyse their progress.
